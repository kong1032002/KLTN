# %% [markdown]
# <a href="https://colab.research.google.com/github/kong1032002/KLTN/blob/main/rugpull_classification_feature_token_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from transformers import BertTokenizer
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers as L
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from tqdm import tqdm
import time
from datetime import datetime
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x7cf116a39480>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:

# %% [markdown]
# **Đọc dữ liệu trainning dataset và chuẩn hóa tên các cột thành lower case**

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Dataset_v1.7.csv")
df.dropna(inplace=True)
df.rename(columns=lambda x: x.lower(), inplace=True)
print(df.shape)
df.head()
# Out:
# (18348, 20)
#                                            id  label  mint_count_per_week  \
# 0  0x79be722ac565ea6e0393b04604b766c6d6a07ed8   True             0.925083
# 1  0x5e58b5210e069fd4dcea10d94e735b0809b6a6b3   True             0.906666
# 2  0xf690325d046cc76b1f88c6d84b9ca7673f1b68ed   True             0.883027
# 3  0x4014f7d9b0d0196da20199c9ad6c3e4251feb9fb   True             0.772323
# 4  0x8b72aceb3e49a4c343ee538ff96b8497ba14575c   True             0.962898
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0                  0.0    0.013158    0.986842         0.0               0.0
# 1                  0.0    0.011765    0.988235         0.0               0.0
# 2                  0.0    0.021739    0.978261         0.0               0.0
# 3                  0.0    0.007092    0.992908         0.0               0.0
# 4                  0.0    0.040000    0.960000         0.0               0.0
#
#    swap_mean_period  burn_mean_period  swapin_per_week  swapout_per_week  \
# 0          0.105351               0.0        69.381244          0.000000
# 1          0.085498               0.0        76.159980          0.000000
# 2          0.084539               0.0        39.736202          0.000000
# 3          0.163984               0.0       108.125227          0.000000
# 4          0.098610               0.0        21.183753          1.925796
#
#     swap_rate  lp_avg  lp_stdev  lpcreator_holding_ratio  lock_ratio  \
# 0   75.000000   100.0       0.0                 0.999666         0.0
# 1   84.000000   100.0       0.0                 0.999522         0.0
# 2   45.000000   100.0       0.0                 0.999132         0.0
# 3  140.000000   100.0       0.0                 0.999491         0.0
# 4    7.333333   100.0       0.0                 1.000497         0.0
#
#    token_burn_ratio  creator_token_holding_ratio  \
# 0               0.0                 8.960000e+02
# 1               0.0                 9.999432e-10
# 2               0.0                 1.351351e-15
# 3               0.0                 5.000000e+06
# 4               0.0                 0.000000e+00
#
#    number_of_token_creation_of_creator
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %% [markdown]
# **Chuyển đổi label của trainning dataframe từ Boolean về Int**

# %%
label_encoder = LabelEncoder()
df["label"] = label_encoder.fit_transform(df["label"])
print(df["label"].value_counts())
df.head()
# Out:
# 1    16511
# 0     1837
# Name: label, dtype: int64
#                                            id  label  mint_count_per_week  \
# 0  0x79be722ac565ea6e0393b04604b766c6d6a07ed8      1             0.925083
# 1  0x5e58b5210e069fd4dcea10d94e735b0809b6a6b3      1             0.906666
# 2  0xf690325d046cc76b1f88c6d84b9ca7673f1b68ed      1             0.883027
# 3  0x4014f7d9b0d0196da20199c9ad6c3e4251feb9fb      1             0.772323
# 4  0x8b72aceb3e49a4c343ee538ff96b8497ba14575c      1             0.962898
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0                  0.0    0.013158    0.986842         0.0               0.0
# 1                  0.0    0.011765    0.988235         0.0               0.0
# 2                  0.0    0.021739    0.978261         0.0               0.0
# 3                  0.0    0.007092    0.992908         0.0               0.0
# 4                  0.0    0.040000    0.960000         0.0               0.0
#
#    swap_mean_period  burn_mean_period  swapin_per_week  swapout_per_week  \
# 0          0.105351               0.0        69.381244          0.000000
# 1          0.085498               0.0        76.159980          0.000000
# 2          0.084539               0.0        39.736202          0.000000
# 3          0.163984               0.0       108.125227          0.000000
# 4          0.098610               0.0        21.183753          1.925796
#
#     swap_rate  lp_avg  lp_stdev  lpcreator_holding_ratio  lock_ratio  \
# 0   75.000000   100.0       0.0                 0.999666         0.0
# 1   84.000000   100.0       0.0                 0.999522         0.0
# 2   45.000000   100.0       0.0                 0.999132         0.0
# 3  140.000000   100.0       0.0                 0.999491         0.0
# 4    7.333333   100.0       0.0                 1.000497         0.0
#
#    token_burn_ratio  creator_token_holding_ratio  \
# 0               0.0                 8.960000e+02
# 1               0.0                 9.999432e-10
# 2               0.0                 1.351351e-15
# 3               0.0                 5.000000e+06
# 4               0.0                 0.000000e+00
#
#    number_of_token_creation_of_creator
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %% [markdown]
# **Đọc dữ liệu test dataset và chuẩn hóa tên các cột thành lower case**

# %%
test_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Dataset_v1.8.csv")
test_df.dropna(inplace=True)
test_df.rename(columns=lambda x: x.lower(), inplace=True)
print(test_df.shape)
test_df.head()
# Out:
# (18334, 20)
#                                            id  label  mint_count_per_week  \
# 0  0xc45681eed9bea2a71cdcc1fa324a40f1d4617285   True             3.624183
# 1  0x624585c31d9c40cca7ef3151d863da150450bf41   True             0.070128
# 2  0x163c9e4df29498537b99e0f729e36e4626576a8b   True             0.979194
# 3  0x45db9c78e5751e06fabf1ed7559607b2c0896652   True             0.998964
# 4  0xcad88d721601a5b440a4398f3bbd288c5d383b32   True             0.994511
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0                  0.0    0.666667    0.333333         0.0          0.267173
# 1                  0.0    0.007143    0.992857         0.0          0.000000
# 2                  0.0    0.050000    0.950000         0.0          0.000000
# 3                  0.0    0.125000    0.875000         0.0          0.000000
# 4                  0.0    0.040000    0.960000         0.0          0.000000
#
#    swap_mean_period  burn_mean_period  swapin_per_week  swapout_per_week  \
# 0          0.036865               0.0         1.812091          0.000000
# 1          0.340321               0.0         4.488208          5.259619
# 2          0.183410               0.0        17.625488          0.979194
# 3          0.234450               0.0         3.995857          2.996893
# 4          0.294488               0.0        16.906689          6.961578
#
#    swap_rate  lp_avg  lp_stdev  lpcreator_holding_ratio  lock_ratio  \
# 0   2.000000   100.0       0.0                 1.000000    0.000000
# 1   0.842105   100.0       0.0                 0.000016    1.000607
# 2   9.000000   100.0       0.0                 0.000000    0.999937
# 3   1.000000   100.0       0.0                 0.250156    0.750467
# 4   2.125000   100.0       0.0                 0.000000    0.999808
#
#    token_burn_ratio  creator_token_holding_ratio  \
# 0          0.000000                 1.160000e+66
# 1          0.000000                 1.040000e+56
# 2          0.314502                 1.000000e+16
# 3          0.000000                 8.333330e+12
# 4          0.000000                 3.000000e+06
#
#    number_of_token_creation_of_creator
# 0                                    2
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %% [markdown]
# **Chuyển đổi label của trainning dataframe từ Boolean về Int**

# %%
test_df["label"] = label_encoder.fit_transform(test_df["label"])
print(test_df["label"].value_counts())
test_df.head()
# Out:
# 1    16498
# 0     1836
# Name: label, dtype: int64
#                                            id  label  mint_count_per_week  \
# 0  0xc45681eed9bea2a71cdcc1fa324a40f1d4617285      1             3.624183
# 1  0x624585c31d9c40cca7ef3151d863da150450bf41      1             0.070128
# 2  0x163c9e4df29498537b99e0f729e36e4626576a8b      1             0.979194
# 3  0x45db9c78e5751e06fabf1ed7559607b2c0896652      1             0.998964
# 4  0xcad88d721601a5b440a4398f3bbd288c5d383b32      1             0.994511
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0                  0.0    0.666667    0.333333         0.0          0.267173
# 1                  0.0    0.007143    0.992857         0.0          0.000000
# 2                  0.0    0.050000    0.950000         0.0          0.000000
# 3                  0.0    0.125000    0.875000         0.0          0.000000
# 4                  0.0    0.040000    0.960000         0.0          0.000000
#
#    swap_mean_period  burn_mean_period  swapin_per_week  swapout_per_week  \
# 0          0.036865               0.0         1.812091          0.000000
# 1          0.340321               0.0         4.488208          5.259619
# 2          0.183410               0.0        17.625488          0.979194
# 3          0.234450               0.0         3.995857          2.996893
# 4          0.294488               0.0        16.906689          6.961578
#
#    swap_rate  lp_avg  lp_stdev  lpcreator_holding_ratio  lock_ratio  \
# 0   2.000000   100.0       0.0                 1.000000    0.000000
# 1   0.842105   100.0       0.0                 0.000016    1.000607
# 2   9.000000   100.0       0.0                 0.000000    0.999937
# 3   1.000000   100.0       0.0                 0.250156    0.750467
# 4   2.125000   100.0       0.0                 0.000000    0.999808
#
#    token_burn_ratio  creator_token_holding_ratio  \
# 0          0.000000                 1.160000e+66
# 1          0.000000                 1.040000e+56
# 2          0.314502                 1.000000e+16
# 3          0.000000                 8.333330e+12
# 4          0.000000                 3.000000e+06
#
#    number_of_token_creation_of_creator
# 0                                    2
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %%
X = df.drop(['label', 'id'], axis = 1)
X_test = test_df.drop(['label', 'id'], axis = 1)
y = pd.get_dummies(df['label'])
y_test = pd.get_dummies(test_df['label'])
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-316fb66bbf34> in <cell line: 1>()
# ----> 1 X = df.drop(['label', 'id'], axis = 1)
#       2 X_test = test_df.drop(['label', 'id'], axis = 1)
#       3 y = pd.get_dummies(df['label'])
#       4 y_test = pd.get_dummies(test_df['label'])
#       5 y
#
# NameError: name 'df' is not defined

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %%
class DataConfig:
    def __init__(self, numeric_feature_names, categorical_features_with_vocabulary):
        self.NUMERIC_FEATURE_NAMES = numeric_feature_names
        self.CATEGORICAL_FEATURES_WITH_VOCABULARY = categorical_features_with_vocabulary
        self.CATEGORICAL_FEATURE_NAMES = list(self.CATEGORICAL_FEATURES_WITH_VOCABULARY.keys())
        self.FEATURE_NAMES = self.NUMERIC_FEATURE_NAMES + self.CATEGORICAL_FEATURE_NAMES

class DataLoader:
    @classmethod
    def from_df(cls, X, y=None, batch_size=1024):
        return (
            Dataset.from_tensor_slices(({col: X[col].values.tolist() for col in X.columns}, y.values.tolist())).batch(
                batch_size
            )
            if y is not None
            else Dataset.from_tensor_slices({col: X[col].values.tolist() for col in X.columns}).batch(batch_size)
        )

# %%
def get_inputs(config):
    return {
        feature_name: L.Input(
            name=feature_name,
            shape=(),
            dtype=(tf.float32 if feature_name in config.NUMERIC_FEATURE_NAMES else tf.string),
        )
        for feature_name in config.FEATURE_NAMES
    }

def encode_inputs(inputs, config, use_embeddings=False, embedding_dim=32, prefix="", concat_features=False):
    cat_features = []
    num_features = []
    for feature_name in inputs:
        if feature_name in config.CATEGORICAL_FEATURE_NAMES:
            vocabulary = config.CATEGORICAL_FEATURES_WITH_VOCABULARY[feature_name]
            lookup = L.StringLookup(
                vocabulary=vocabulary,
                mask_token=None,
                num_oov_indices=0,
                output_mode="int" if use_embeddings else "binary",
                name=f"{prefix}{feature_name}_lookup",
            )
            if use_embeddings:
                encoded_feature = lookup(inputs[feature_name])
                embedding = L.Embedding(
                    input_dim=len(vocabulary),
                    output_dim=embedding_dim,
                    name=f"{prefix}{feature_name}_embeddings",
                )
                encoded_feature = embedding(encoded_feature)
            else:
                encoded_feature = lookup(
                    L.Reshape((1,), name=f"{prefix}{feature_name}_reshape")(inputs[feature_name])
                )
            cat_features.append(encoded_feature)
        else:
            encoded_feature = L.Reshape((1,), name=f"{prefix}{feature_name}_reshape")(inputs[feature_name])
            num_features.append(encoded_feature)

    features = (
        L.Concatenate(name=f"{prefix}inputs_concatenate")(cat_features + num_features)
        if concat_features
        else (cat_features, num_features)
    )

    return features

# %%
class FeatureTokenizerTransformerConfig:
    def __init__(
        self,
        num_outputs,
        out_activation,
        num_transformer_blocks=2,
        num_heads=8,
        embedding_dim=32,
        dense_dim=16,
    ):
        self.NUM_OUT = num_outputs
        self.OUT_ACTIVATION = out_activation
        self.NUM_TRANSFORMER_BLOCKS = num_transformer_blocks
        self.NUM_HEADS = num_heads
        self.EMBEDDING_DIM = embedding_dim
        self.DENSE_DIM = dense_dim

# %%
class TransformerBlock(L.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = L.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = tf.keras.Sequential([L.Dense(dense_dim, activation="relu"), L.Dense(embed_dim)])
        self.layernorm1 = L.LayerNormalization()
        self.layernorm2 = L.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[: tf.newaxis, :]
        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm2(proj_input + proj_output)

# %%
class FeatureTokenizerTransformer:
    @classmethod
    def from_config(cls, data_config, model_config, name):
        inputs = get_inputs(data_config)
        cat_features, num_features = encode_inputs(
            inputs,
            data_config,
            use_embeddings=True,
            embedding_dim=model_config.EMBEDDING_DIM,
            prefix="",
            concat_features=False,
        )
        num_feat_emb = [
            L.Dense(model_config.EMBEDDING_DIM, name=f"{feature_name}_embeddings")
            for _, feature_name in zip(range(len(num_features)), data_config.NUMERIC_FEATURE_NAMES)
        ]
        num_features = [emb(feat) for emb, feat in zip(num_feat_emb, num_features)]

        features = L.Concatenate(axis=1, name="feature_embeddings_stack")(
            [
                L.Reshape((1, 32), name=f"{feat_name}_reshape_2")(feat)
                for feat, feat_name in zip((num_features + cat_features), data_config.FEATURE_NAMES)
            ]
        )

        for _ in range(model_config.NUM_TRANSFORMER_BLOCKS):
            features = TransformerBlock(
                embed_dim=model_config.EMBEDDING_DIM,
                dense_dim=model_config.DENSE_DIM,
                num_heads=model_config.NUM_HEADS,
            )(features)
        features = L.GlobalMaxPooling1D()(features)
        outputs = L.Dense(
            units=model_config.NUM_OUT,
            activation=model_config.OUT_ACTIVATION,
            name="outputs",
        )(features)
        model = keras.Model(inputs=inputs, outputs=outputs, name=name)
        return model

# %%
data_config = DataConfig(
    numeric_feature_names=X.columns.tolist(), categorical_features_with_vocabulary={}
)
model_config = FeatureTokenizerTransformerConfig(num_outputs=len(y.columns), out_activation='softmax')

# %%
blank_model = FeatureTokenizerTransformer.from_config(data_config, model_config, name='ftt')
blank_model.summary()
# Out:
# Model: "ftt"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  mint_count_per_week (Input  [(None,)]                    0         []
#  Layer)
#
#  burn_count_per_week (Input  [(None,)]                    0         []
#  Layer)
#
#  mint_ratio (InputLayer)     [(None,)]                    0         []
#
#  swap_ratio (InputLayer)     [(None,)]                    0         []
#
#  burn_ratio (InputLayer)     [(None,)]                    0         []
#
#  mint_mean_period (InputLay  [(None,)]                    0         []
#  er)
#
#  swap_mean_period (InputLay  [(None,)]                    0         []
#  er)
#
#  burn_mean_period (InputLay  [(None,)]                    0         []
#  er)
#
#  swapin_per_week (InputLaye  [(None,)]                    0         []
#  r)
#
#  swapout_per_week (InputLay  [(None,)]                    0         []
#  er)
#
#  swap_rate (InputLayer)      [(None,)]                    0         []
#
#  lp_avg (InputLayer)         [(None,)]                    0         []
#
#  lp_stdev (InputLayer)       [(None,)]                    0         []
#
#  lpcreator_holding_ratio (I  [(None,)]                    0         []
#  nputLayer)
#
#  lock_ratio (InputLayer)     [(None,)]                    0         []
#
#  token_burn_ratio (InputLay  [(None,)]                    0         []
#  er)
#
#  creator_token_holding_rati  [(None,)]                    0         []
#  o (InputLayer)
#
#  number_of_token_creation_o  [(None,)]                    0         []
#  f_creator (InputLayer)
#
#  mint_count_per_week_reshap  (None, 1)                    0         ['mint_count_per_week[0][0]']
#  e (Reshape)
#
#  burn_count_per_week_reshap  (None, 1)                    0         ['burn_count_per_week[0][0]']
#  e (Reshape)
#
#  mint_ratio_reshape (Reshap  (None, 1)                    0         ['mint_ratio[0][0]']
#  e)
#
#  swap_ratio_reshape (Reshap  (None, 1)                    0         ['swap_ratio[0][0]']
#  e)
#
#  burn_ratio_reshape (Reshap  (None, 1)                    0         ['burn_ratio[0][0]']
#  e)
#
#  mint_mean_period_reshape (  (None, 1)                    0         ['mint_mean_period[0][0]']
#  Reshape)
#
#  swap_mean_period_reshape (  (None, 1)                    0         ['swap_mean_period[0][0]']
#  Reshape)
#
#  burn_mean_period_reshape (  (None, 1)                    0         ['burn_mean_period[0][0]']
#  Reshape)
#
#  swapin_per_week_reshape (R  (None, 1)                    0         ['swapin_per_week[0][0]']
#  eshape)
#
#  swapout_per_week_reshape (  (None, 1)                    0         ['swapout_per_week[0][0]']
#  Reshape)
#
#  swap_rate_reshape (Reshape  (None, 1)                    0         ['swap_rate[0][0]']
#  )
#
#  lp_avg_reshape (Reshape)    (None, 1)                    0         ['lp_avg[0][0]']
#
#  lp_stdev_reshape (Reshape)  (None, 1)                    0         ['lp_stdev[0][0]']
#
#  lpcreator_holding_ratio_re  (None, 1)                    0         ['lpcreator_holding_ratio[0][0
#  shape (Reshape)                                                    ]']
#
#  lock_ratio_reshape (Reshap  (None, 1)                    0         ['lock_ratio[0][0]']
#  e)
#
#  token_burn_ratio_reshape (  (None, 1)                    0         ['token_burn_ratio[0][0]']
#  Reshape)
#
#  creator_token_holding_rati  (None, 1)                    0         ['creator_token_holding_ratio[
#  o_reshape (Reshape)                                                0][0]']
#
#  number_of_token_creation_o  (None, 1)                    0         ['number_of_token_creation_of_
#  f_creator_reshape (Reshape                                         creator[0][0]']
#  )
#
#  mint_count_per_week_embedd  (None, 32)                   64        ['mint_count_per_week_reshape[
#  ings (Dense)                                                       0][0]']
#
#  burn_count_per_week_embedd  (None, 32)                   64        ['burn_count_per_week_reshape[
#  ings (Dense)                                                       0][0]']
#
#  mint_ratio_embeddings (Den  (None, 32)                   64        ['mint_ratio_reshape[0][0]']
#  se)
#
#  swap_ratio_embeddings (Den  (None, 32)                   64        ['swap_ratio_reshape[0][0]']
#  se)
#
#  burn_ratio_embeddings (Den  (None, 32)                   64        ['burn_ratio_reshape[0][0]']
#  se)
#
#  mint_mean_period_embedding  (None, 32)                   64        ['mint_mean_period_reshape[0][
#  s (Dense)                                                          0]']
#
#  swap_mean_period_embedding  (None, 32)                   64        ['swap_mean_period_reshape[0][
#  s (Dense)                                                          0]']
#
#  burn_mean_period_embedding  (None, 32)                   64        ['burn_mean_period_reshape[0][
#  s (Dense)                                                          0]']
#
#  swapin_per_week_embeddings  (None, 32)                   64        ['swapin_per_week_reshape[0][0
#   (Dense)                                                           ]']
#
#  swapout_per_week_embedding  (None, 32)                   64        ['swapout_per_week_reshape[0][
#  s (Dense)                                                          0]']
#
#  swap_rate_embeddings (Dens  (None, 32)                   64        ['swap_rate_reshape[0][0]']
#  e)
#
#  lp_avg_embeddings (Dense)   (None, 32)                   64        ['lp_avg_reshape[0][0]']
#
#  lp_stdev_embeddings (Dense  (None, 32)                   64        ['lp_stdev_reshape[0][0]']
#  )
#
#  lpcreator_holding_ratio_em  (None, 32)                   64        ['lpcreator_holding_ratio_resh
#  beddings (Dense)                                                   ape[0][0]']
#
#  lock_ratio_embeddings (Den  (None, 32)                   64        ['lock_ratio_reshape[0][0]']
#  se)
#
#  token_burn_ratio_embedding  (None, 32)                   64        ['token_burn_ratio_reshape[0][
#  s (Dense)                                                          0]']
#
#  creator_token_holding_rati  (None, 32)                   64        ['creator_token_holding_ratio_
#  o_embeddings (Dense)                                               reshape[0][0]']
#
#  number_of_token_creation_o  (None, 32)                   64        ['number_of_token_creation_of_
#  f_creator_embeddings (Dens                                         creator_reshape[0][0]']
#  e)
#
#  mint_count_per_week_reshap  (None, 1, 32)                0         ['mint_count_per_week_embeddin
#  e_2 (Reshape)                                                      gs[0][0]']
#
#  burn_count_per_week_reshap  (None, 1, 32)                0         ['burn_count_per_week_embeddin
#  e_2 (Reshape)                                                      gs[0][0]']
#
#  mint_ratio_reshape_2 (Resh  (None, 1, 32)                0         ['mint_ratio_embeddings[0][0]'
#  ape)                                                               ]
#
#  swap_ratio_reshape_2 (Resh  (None, 1, 32)                0         ['swap_ratio_embeddings[0][0]'
#  ape)                                                               ]
#
#  burn_ratio_reshape_2 (Resh  (None, 1, 32)                0         ['burn_ratio_embeddings[0][0]'
#  ape)                                                               ]
#
#  mint_mean_period_reshape_2  (None, 1, 32)                0         ['mint_mean_period_embeddings[
#   (Reshape)                                                         0][0]']
#
#  swap_mean_period_reshape_2  (None, 1, 32)                0         ['swap_mean_period_embeddings[
#   (Reshape)                                                         0][0]']
#
#  burn_mean_period_reshape_2  (None, 1, 32)                0         ['burn_mean_period_embeddings[
#   (Reshape)                                                         0][0]']
#
#  swapin_per_week_reshape_2   (None, 1, 32)                0         ['swapin_per_week_embeddings[0
#  (Reshape)                                                          ][0]']
#
#  swapout_per_week_reshape_2  (None, 1, 32)                0         ['swapout_per_week_embeddings[
#   (Reshape)                                                         0][0]']
#
#  swap_rate_reshape_2 (Resha  (None, 1, 32)                0         ['swap_rate_embeddings[0][0]']
#  pe)
#
#  lp_avg_reshape_2 (Reshape)  (None, 1, 32)                0         ['lp_avg_embeddings[0][0]']
#
#  lp_stdev_reshape_2 (Reshap  (None, 1, 32)                0         ['lp_stdev_embeddings[0][0]']
#  e)
#
#  lpcreator_holding_ratio_re  (None, 1, 32)                0         ['lpcreator_holding_ratio_embe
#  shape_2 (Reshape)                                                  ddings[0][0]']
#
#  lock_ratio_reshape_2 (Resh  (None, 1, 32)                0         ['lock_ratio_embeddings[0][0]'
#  ape)                                                               ]
#
#  token_burn_ratio_reshape_2  (None, 1, 32)                0         ['token_burn_ratio_embeddings[
#   (Reshape)                                                         0][0]']
#
#  creator_token_holding_rati  (None, 1, 32)                0         ['creator_token_holding_ratio_
#  o_reshape_2 (Reshape)                                              embeddings[0][0]']
#
#  number_of_token_creation_o  (None, 1, 32)                0         ['number_of_token_creation_of_
#  f_creator_reshape_2 (Resha                                         creator_embeddings[0][0]']
#  pe)
#
#  feature_embeddings_stack (  (None, 18, 32)               0         ['mint_count_per_week_reshape_
#  Concatenate)                                                       2[0][0]',
#                                                                      'burn_count_per_week_reshape_
#                                                                     2[0][0]',
#                                                                      'mint_ratio_reshape_2[0][0]',
#                                                                      'swap_ratio_reshape_2[0][0]',
#                                                                      'burn_ratio_reshape_2[0][0]',
#                                                                      'mint_mean_period_reshape_2[0
#                                                                     ][0]',
#                                                                      'swap_mean_period_reshape_2[0
#                                                                     ][0]',
#                                                                      'burn_mean_period_reshape_2[0
#                                                                     ][0]',
#                                                                      'swapin_per_week_reshape_2[0]
#                                                                     [0]',
#                                                                      'swapout_per_week_reshape_2[0
#                                                                     ][0]',
#                                                                      'swap_rate_reshape_2[0][0]',
#                                                                      'lp_avg_reshape_2[0][0]',
#                                                                      'lp_stdev_reshape_2[0][0]',
#                                                                      'lpcreator_holding_ratio_resh
#                                                                     ape_2[0][0]',
#                                                                      'lock_ratio_reshape_2[0][0]',
#                                                                      'token_burn_ratio_reshape_2[0
#                                                                     ][0]',
#                                                                      'creator_token_holding_ratio_
#                                                                     reshape_2[0][0]',
#                                                                      'number_of_token_creation_of_
#                                                                     creator_reshape_2[0][0]']
#
#  transformer_block (Transfo  (None, 18, 32)               34768     ['feature_embeddings_stack[0][
#  rmerBlock)                                                         0]']
#
#  transformer_block_1 (Trans  (None, 18, 32)               34768     ['transformer_block[0][0]']
#  formerBlock)
#
#  global_max_pooling1d (Glob  (None, 32)                   0         ['transformer_block_1[0][0]']
#  alMaxPooling1D)
#
#  outputs (Dense)             (None, 2)                    66        ['global_max_pooling1d[0][0]']
#
# ==================================================================================================
# Total params: 70754 (276.38 KB)
# Trainable params: 70754 (276.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
MAX_EPOCHS  = 50

get_callbacks = lambda : [
    keras.callbacks.EarlyStopping(min_delta=1e-4, patience=3, verbose=1, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(patience=2, verbose=1)
]

# %%
from tensorflow.data import Dataset
preds = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, df['label'])):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

    scaler = StandardScaler().fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_valid = pd.DataFrame(scaler.transform(X_valid), columns=X.columns)
    x_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

    data_train = DataLoader.from_df(X_train, y_train, batch_size=512)
    data_valid = DataLoader.from_df(X_valid, y_valid, batch_size=512)
    data_test = DataLoader.from_df(x_test, batch_size=512)

    model = FeatureTokenizerTransformer.from_config(data_config, model_config, name=f'ftt_fold_{fold}')
    model.compile(
        loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy']
    )
    model.fit(
        data_train, validation_data=data_valid, callbacks=get_callbacks(),
        epochs=MAX_EPOCHS
    )
    preds.append(model.predict(data_test))
# Out:
# Epoch 1/50
# 29/29 [==============================] - 15s 63ms/step - loss: 0.3077 - accuracy: 0.8888 - val_loss: 0.1668 - val_accuracy: 0.9387 - lr: 0.0010
# Epoch 2/50
# 29/29 [==============================] - 1s 29ms/step - loss: 0.1682 - accuracy: 0.9418 - val_loss: 0.1408 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 3/50
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1970 - accuracy: 0.9227 - val_loss: 0.1359 - val_accuracy: 0.9531 - lr: 0.0010
# Epoch 4/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.
50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0886 - accuracy: 0.9659 - val_loss: 0.1057 - val_accuracy: 0.9553 - lr: 1.0000e-04
# 36/36 [==============================] - 1s 16ms/step
# Epoch 1/50
# 29/29 [==============================] - 16s 87ms/step - loss: 0.2235 - accuracy: 0.9073 - val_loss: 0.1577 - val_accuracy: 0.9319 - lr: 0.0010
# Epoch 2/50
# 29/29 [==============================] - 1s 38ms/step - loss: 0.1666 - accuracy: 0.9262 - val_loss: 0.2239 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 3/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1591 - accuracy: 0.9379 - val_loss: 0.1276 - val_accuracy: 0.9569 - lr: 0.0010
# Epoch 4/50
# 29/29 [==============================] - 1s 48ms/step - loss: 0.1336 - accuracy: 0.9459 - val_loss: 0.1274 - val_accuracy: 0.9586 - lr: 0.0010
# Epoch 5/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1277 - accuracy: 0.9526 - val_loss: 0.1208 - val_accuracy: 0.9599 - lr: 0.0010
# Epoch 6/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1253 - accuracy: 0.9530 - val_loss: 0.1212 - val_accuracy: 0.9599 - lr: 0.0010
# Epoch 7/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1230 - accuracy: 0.9539 - val_loss: 0.1185 - val_accuracy: 0.9597 - lr: 0.0010
# Epoch 8/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1197 - accuracy: 0.9561 - val_loss: 0.1156 - val_accuracy: 0.9638 - lr: 0.0010
# Epoch 9/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1251 - accuracy: 0.9474 - val_loss: 0.1283 - val_accuracy: 0.9591 - lr: 0.0010
# Epoch 10/50
# 28/29 [===========================>..] - ETA: 0s - loss: 0.1176 - accuracy: 0.9534
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 29/29 [==============================] - 1s 48ms/step - loss: 0.1221 - accuracy: 0.9521 - val_loss: 0.1174 - val_accuracy: 0.9613 - lr: 0.0010
# Epoch 11/50
# 29/29 [==============================] - 2s 57ms/step - loss: 0.1130 - accuracy: 0.9605 - val_loss: 0.1119 - val_accuracy: 0.9632 - lr: 1.0000e-04
# Epoch 12/50
# 29/29 [==============================] - 1s 39ms/step - loss: 0.1105 - accuracy: 0.9603 - val_loss: 0.1109 - val_accuracy: 0.9638 - lr: 1.0000e-04
# Epoch 13/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1094 - accuracy: 0.9606 - val_loss: 0.1100 - val_accuracy: 0.9643 - lr: 1.0000e-04
# Epoch 14/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1088 - accuracy: 0.9608 - val_loss: 0.1093 - val_accuracy: 0.9640 - lr: 1.0000e-04
# Epoch 15/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1080 - accuracy: 0.9610 - val_loss: 0.1087 - val_accuracy: 0.9646 - lr: 1.0000e-04
# Epoch 16/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1075 - accuracy: 0.9607 - val_loss: 0.1081 - val_accuracy: 0.9648 - lr: 1.0000e-04
# Epoch 17/50
# 29/29 [==============================] - 1s 38ms/step - loss: 0.1069 - accuracy: 0.9609 - val_loss: 0.1076 - val_accuracy: 0.9646 - lr: 1.0000e-04
# Epoch 18/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1064 - accuracy: 0.9608 - val_loss: 0.1072 - val_accuracy: 0.9651 - lr: 1.0000e-04
# Epoch 19/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1058 - accuracy: 0.9610 - val_loss: 0.1067 - val_accuracy: 0.9648 - lr: 1.0000e-04
# Epoch 20/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1055 - accuracy: 0.9612 - val_loss: 0.1063 - val_accuracy: 0.9651 - lr: 1.0000e-04
# Epoch 21/50
# 29/29 [==============================] - 2s 54ms/step - loss: 0.1049 - accuracy: 0.9611 - val_loss: 0.1059 - val_accuracy: 0.9648 - lr: 1.0000e-04
# Epoch 22/50
# 29/29 [==============================] - 2s 56ms/step - loss: 0.1052 - accuracy: 0.9611 - val_loss: 0.1056 - val_accuracy: 0.9654 - lr: 1.0000e-04
# Epoch 23/50
# 29/29 [==============================] - 2s 56ms/step - loss: 0.1053 - accuracy: 0.9609 - val_loss: 0.1052 - val_accuracy: 0.9648 - lr: 1.0000e-04
# Epoch 24/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1083 - accuracy: 0.9579 - val_loss: 0.1053 - val_accuracy: 0.9654 - lr: 1.0000e-04
# Epoch 25/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9597
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1110 - accuracy: 0.9597 - val_loss: 0.1059 - val_accuracy: 0.9627 - lr: 1.0000e-04
# Epoch 26/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1028 - accuracy: 0.9612 - val_loss: 0.1051 - val_accuracy: 0.9646 - lr: 1.0000e-05
# Epoch 27/50
# 29/29 [==============================] - 1s 38ms/step - loss: 0.1027 - accuracy: 0.9614 - val_loss: 0.1049 - val_accuracy: 0.9648 - lr: 1.0000e-05
# Epoch 28/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1025 - accuracy: 0.9614 - val_loss: 0.1048 - val_accuracy: 0.9648 - lr: 1.0000e-05
# Epoch 29/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1024 - accuracy: 0.9613 - val_loss: 0.1047 - val_accuracy: 0.9648 - lr: 1.0000e-05
# Epoch 30/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1023 - accuracy: 0.9614 - val_loss: 0.1046 - val_accuracy: 0.9648 - lr: 1.0000e-05
# Epoch 31/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1022 - accuracy: 0.9614 - val_loss: 0.1046 - val_accuracy: 0.9651 - lr: 1.0000e-05
# Epoch 32/50
# 29/29 [==============================] - 1s 48ms/step - loss: 0.1022 - accuracy: 0.9614 - val_loss: 0.1045 - val_accuracy: 0.9651 - lr: 1.0000e-05
# Epoch 33/50
# 29/29 [==============================] - 1s 48ms/step - loss: 0.1021 - accuracy: 0.9614 - val_loss: 0.1045 - val_accuracy: 0.9651 - lr: 1.0000e-05
# Epoch 34/50
# 29/29 [==============================] - 2s 53ms/step - loss: 0.1020 - accuracy: 0.9615 - val_loss: 0.1044 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 35/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1019 - accuracy: 0.9616 - val_loss: 0.1044 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 36/50
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0991 - accuracy: 0.9623
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1019 - accuracy: 0.9616 - val_loss: 0.1043 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 37/50
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0990 - accuracy: 0.9623Restoring model weights from the end of the best epoch: 34.
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1018 - accuracy: 0.9616 - val_loss: 0.1043 - val_accuracy: 0.9654 - lr: 1.0000e-06
# Epoch 37: early stopping
# 36/36 [==============================] - 1s 15ms/step
# Epoch 1/50
# 29/29 [==============================] - 13s 62ms/step - loss: 0.1654 - accuracy: 0.9369 - val_loss: 0.1590 - val_accuracy: 0.9346 - lr: 0.0010
# Epoch 2/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1626 - accuracy: 0.9255 - val_loss: 0.2561 - val_accuracy: 0.9133 - lr: 0.0010
# Epoch 3/50
# 27/29 [==========================>...] - ETA: 0s - loss: 0.1363 - accuracy: 0.9462
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 29/29 [==============================] - 1s 34ms/step - loss: 0.1579 - accuracy: 0.9339 - val_loss: 0.1757 - val_accuracy: 0.9387 - lr: 0.0010
# Epoch 4/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1506 - accuracy: 0.9520 - val_loss: 0.1321 - val_accuracy: 0.9537 - lr: 1.0000e-04
# Epoch 5/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1301 - accuracy: 0.9492 - val_loss: 0.1302 - val_accuracy: 0.9526 - lr: 1.0000e-04
# Epoch 6/50
# 29/29 [==============================] - 1s 51ms/step - loss: 0.1264 - accuracy: 0.9543 - val_loss: 0.1282 - val_accuracy: 0.9548 - lr: 1.0000e-04
# Epoch 7/50
# 29/29 [==============================] - 1s 48ms/step - loss: 0.1250 - accuracy: 0.9539 - val_loss: 0.1268 - val_accuracy: 0.9550 - lr: 1.0000e-04
# Epoch 8/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.1235 - accuracy: 0.9549 - val_loss: 0.1255 - val_accuracy: 0.9553 - lr: 1.0000e-04
# Epoch 9/50
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1224 - accuracy: 0.9550 - val_loss: 0.1244 - val_accuracy: 0.9558 - lr: 1.0000e-04
# Epoch 10/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.1212 - accuracy: 0.9562 - val_loss: 0.1234 - val_accuracy: 0.9558 - lr: 1.0000e-04
# Epoch 11/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.1203 - accuracy: 0.9564 - val_loss: 0.1225 - val_accuracy: 0.9567 - lr: 1.0000e-04
# Epoch 12/50
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1193 - accuracy: 0.9571 - val_loss: 0.1216 - val_accuracy: 0.9572 - lr: 1.0000e-04
# Epoch 13/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1186 - accuracy: 0.9575 - val_loss: 0.1208 - val_accuracy: 0.9575 - lr: 1.0000e-04
# Epoch 14/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1175 - accuracy: 0.9579 - val_loss: 0.1200 - val_accuracy: 0.9580 - lr: 1.0000e-04
# Epoch 15/50
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1174 - accuracy: 0.9574 - val_loss: 0.1192 - val_accuracy: 0.9583 - lr: 1.0000e-04
# Epoch 16/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1161 - accuracy: 0.9585 - val_loss: 0.1185 - val_accuracy: 0.9580 - lr: 1.0000e-04
# Epoch 17/50
# 29/29 [==============================] - 1s 42ms/step - loss: 0.1185 - accuracy: 0.9534 - val_loss: 0.1178 - val_accuracy: 0.9575 - lr: 1.0000e-04
# Epoch 18/50
# 29/29 [==============================] - 1s 42ms/step - loss: 0.1190 - accuracy: 0.9547 - val_loss: 0.1178 - val_accuracy: 0.9586 - lr: 1.0000e-04
# Epoch 19/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9418
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 29/29 [==============================] - 1s 52ms/step - loss: 0.1265 - accuracy: 0.9418 - val_loss: 0.1184 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 20/50
# 29/29 [==============================] - 1s 50ms/step - loss: 0.1138 - accuracy: 0.9593 - val_loss: 0.1168 - val_accuracy: 0.9575 - lr: 1.0000e-05
# Epoch 21/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1135 - accuracy: 0.9597 - val_loss: 0.1165 - val_accuracy: 0.9569 - lr: 1.0000e-05
# Epoch 22/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1132 - accuracy: 0.9597 - val_loss: 0.1163 - val_accuracy: 0.9564 - lr: 1.0000e-05
# Epoch 23/50
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1130 - accuracy: 0.9597 - val_loss: 0.1161 - val_accuracy: 0.9572 - lr: 1.0000e-05
# Epoch 24/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1128 - accuracy: 0.9599 - val_loss: 0.1160 - val_accuracy: 0.9580 - lr: 1.0000e-05
# Epoch 25/50
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1126 - accuracy: 0.9598 - val_loss: 0.1159 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 26/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1124 - accuracy: 0.9600 - val_loss: 0.1159 - val_accuracy: 0.9588 - lr: 1.0000e-05
# Epoch 27/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1123 - accuracy: 0.9601 - val_loss: 0.1158 - val_accuracy: 0.9588 - lr: 1.0000e-05
# Epoch 28/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1122 - accuracy: 0.9601 - val_loss: 0.1157 - val_accuracy: 0.9588 - lr: 1.0000e-05
# Epoch 29/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1120 - accuracy: 0.9601 - val_loss: 0.1156 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 30/50
# 29/29 [==============================] - 2s 54ms/step - loss: 0.1119 - accuracy: 0.9601 - val_loss: 0.1155 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 31/50
# 29/29 [==============================] - 1s 51ms/step - loss: 0.1118 - accuracy: 0.9603 - val_loss: 0.1155 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 32/50
# 29/29 [==============================] - 1s 38ms/step - loss: 0.1117 - accuracy: 0.9604 - val_loss: 0.1154 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 33/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1116 - accuracy: 0.9604 - val_loss: 0.1153 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 34/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1114 - accuracy: 0.9604 - val_loss: 0.1152 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 35/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.1113 - accuracy: 0.9604 - val_loss: 0.1152 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 36/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1112 - accuracy: 0.9604 - val_loss: 0.1151 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 37/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1111 - accuracy: 0.9604 - val_loss: 0.1150 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 38/50
# 29/29 [==============================] - 1s 38ms/step - loss: 0.1110 - accuracy: 0.9604 - val_loss: 0.1149 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 39/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1109 - accuracy: 0.9604 - val_loss: 0.1148 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 40/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1108 - accuracy: 0.9604 - val_loss: 0.1147 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 41/50
# 29/29 [==============================] - 2s 54ms/step - loss: 0.1107 - accuracy: 0.9604 - val_loss: 0.1146 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 42/50
# 29/29 [==============================] - 2s 58ms/step - loss: 0.1106 - accuracy: 0.9604 - val_loss: 0.1145 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 43/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1105 - accuracy: 0.9604 - val_loss: 0.1144 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 44/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1104 - accuracy: 0.9604 - val_loss: 0.1144 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 45/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1103 - accuracy: 0.9605 - val_loss: 0.1143 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 46/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1102 - accuracy: 0.9605 - val_loss: 0.1142 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 47/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.1101 - accuracy: 0.9605 - val_loss: 0.1141 - val_accuracy: 0.9594 - lr: 1.0000e-05
# Epoch 48/50
# 29/29 [==============================] - 1s 42ms/step - loss: 0.1100 - accuracy: 0.9605 - val_loss: 0.1140 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 49/50
# 29/29 [==============================] - 2s 55ms/step - loss: 0.1099 - accuracy: 0.9605 - val_loss: 0.1139 - val_accuracy: 0.9591 - lr: 1.0000e-05
# Epoch 50/50
# 29/29 [==============================] - 2s 57ms/step - loss: 0.1098 - accuracy: 0.9605 - val_loss: 0.1138 - val_accuracy: 0.9594 - lr: 1.0000e-05
# 36/36 [==============================] - 2s 23ms/step

# %%
submissions = pd.read_csv('../input/tabular-playground-series-feb-2022/sample_submission.csv')
submissions['target'] = pd.DataFrame(
    np.array([arr for arr in preds]).mean(axis=0),columns=y.columns
).idxmax(axis=1).values.tolist()
submissions.to_csv('preds.csv', index=False)
